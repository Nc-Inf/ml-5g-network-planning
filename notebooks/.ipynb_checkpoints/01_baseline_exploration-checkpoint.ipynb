# %% [markdown]
# # Baseline ML for 5G Coverage Proxy
#
# This notebook explores a simple regression baseline to understand how
# base-station placement parameters influence coverage quality.

# %%
import numpy as np
import matplotlib.pyplot as plt
from src.baseline_model import generate_synthetic_data

# %%
X, y = generate_synthetic_data(n_samples=2000, random_state=42)

distance = X[:, 0]
density  = X[:, 1]
tx_power = X[:, 2]

len(y), y[:5]
# Out:
# (2000,
#  array([-19.80590722, -18.95921079, -17.41116065, -28.24534639,
#          -7.78036978]))

# %%
plt.scatter(distance, y, alpha=0.4)
plt.xlabel("Distance to Base Station (m)")
plt.ylabel("Coverage Quality (proxy)")
plt.title("Coverage vs Distance (synthetic baseline)")
plt.grid(True)
plt.show()

# %%
plt.figure()
plt.scatter(distance, y, alpha=0.4)
plt.xlabel("Distance to Base Station (m)")
plt.ylabel("Coverage Quality (proxy)")
plt.title("Coverage vs Distance (synthetic baseline)")
plt.grid(True)

plt.savefig("../results/coverage_vs_distance.png", dpi=200, bbox_inches="tight")
plt.show()
